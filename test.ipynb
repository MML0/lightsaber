# %%
esp_ip = [
    {'ip': '192.168.43.101', 'revers': False},
    {'ip': '192.168.43.102', 'revers': False},
    {'ip': '192.168.43.103', 'revers': False},
]
esp_ip = [
    {'ip': f'192.168.43.{i}', 'revers': False}
    for i in range(101, 110)
]

esp_ip = [
    {'ip': '192.168.43.191', 'revers': False},
    {'ip': '192.168.43.145', 'revers': False},
    {'ip': '192.168.43.123', 'revers': False},
    {'ip': '192.168.43.168', 'revers': False},
    {'ip': '192.168.43.101', 'revers': False},
    {'ip': '192.168.43.102', 'revers': False},
    {'ip': '192.168.43.103', 'revers': False},
    {'ip': '192.168.43.104', 'revers': False},
    {'ip': '192.168.43.105', 'revers': False},
    {'ip': '192.168.43.106', 'revers': False},
    {'ip': '192.168.43.107', 'revers': False},
    {'ip': '192.168.43.108', 'revers': False},
    {'ip': '192.168.43.109', 'revers': False},
    {'ip': '192.168.43.110', 'revers': False},
    {'ip': '192.168.43.111', 'revers': False},
    {'ip': '192.168.43.112', 'revers': False},
    {'ip': '192.168.43.113', 'revers': False},
    {'ip': '192.168.43.114', 'revers': False},
    {'ip': '192.168.43.115', 'revers': False},
    {'ip': '192.168.43.116', 'revers': False},
    {'ip': '192.168.43.117', 'revers': False},
    {'ip': '192.168.43.118', 'revers': False},
    {'ip': '192.168.43.119', 'revers': False},
    {'ip': '192.168.43.120', 'revers': False},
    {'ip': '192.168.43.121', 'revers': False},
    {'ip': '192.168.43.122', 'revers': False},
    {'ip': '192.168.43.124', 'revers': False},
    {'ip': '192.168.43.125', 'revers': False},
    {'ip': '192.168.43.126', 'revers': False},
    {'ip': '192.168.43.127', 'revers': False},
    {'ip': '192.168.43.128', 'revers': False},
    {'ip': '192.168.43.129', 'revers': False},
    {'ip': '192.168.43.130', 'revers': False},
    {'ip': '192.168.43.131', 'revers': False},
    {'ip': '192.168.43.132', 'revers': False},
    {'ip': '192.168.43.133', 'revers': False},
    {'ip': '192.168.43.134', 'revers': False},
    {'ip': '192.168.43.135', 'revers': False},
    {'ip': '192.168.43.136', 'revers': False},
    {'ip': '192.168.43.137', 'revers': False},
    {'ip': '192.168.43.138', 'revers': False},
    {'ip': '192.168.43.139', 'revers': False},
    {'ip': '192.168.43.140', 'revers': False},
    {'ip': '192.168.43.141', 'revers': False},
    {'ip': '192.168.43.142', 'revers': False},
    {'ip': '192.168.43.143', 'revers': False},
    {'ip': '192.168.43.144', 'revers': False},
    {'ip': '192.168.43.146', 'revers': False},
    {'ip': '192.168.43.147', 'revers': False},
    {'ip': '192.168.43.148', 'revers': False},
    {'ip': '192.168.43.149', 'revers': False},
    {'ip': '192.168.43.150', 'revers': False},
    {'ip': '192.168.43.151', 'revers': False},
    {'ip': '192.168.43.152', 'revers': False},
    {'ip': '192.168.43.153', 'revers': False},
    {'ip': '192.168.43.154', 'revers': False},
    {'ip': '192.168.43.155', 'revers': False},
    {'ip': '192.168.43.156', 'revers': False},
    {'ip': '192.168.43.157', 'revers': False},
    {'ip': '192.168.43.158', 'revers': False},
    {'ip': '192.168.43.159', 'revers': False},
    {'ip': '192.168.43.160', 'revers': False},
    {'ip': '192.168.43.161', 'revers': False},
    {'ip': '192.168.43.162', 'revers': False},
    {'ip': '192.168.43.163', 'revers': False},
    {'ip': '192.168.43.164', 'revers': False},
    {'ip': '192.168.43.165', 'revers': False},
    {'ip': '192.168.43.166', 'revers': False},
    {'ip': '192.168.43.167', 'revers': False},
    {'ip': '192.168.43.169', 'revers': False},
    {'ip': '192.168.43.170', 'revers': False},
    {'ip': '192.168.43.171', 'revers': False},
    {'ip': '192.168.43.172', 'revers': False},
    {'ip': '192.168.43.173', 'revers': False},
    {'ip': '192.168.43.174', 'revers': False},
    {'ip': '192.168.43.175', 'revers': False},
    {'ip': '192.168.43.176', 'revers': False},
    {'ip': '192.168.43.177', 'revers': False},
    {'ip': '192.168.43.178', 'revers': False},
    {'ip': '192.168.43.179', 'revers': False},
    {'ip': '192.168.43.180', 'revers': False},
    {'ip': '192.168.43.181', 'revers': False},
    {'ip': '192.168.43.182', 'revers': False},
    {'ip': '192.168.43.183', 'revers': False},
    {'ip': '192.168.43.184', 'revers': False},
    {'ip': '192.168.43.185', 'revers': False},
    {'ip': '192.168.43.186', 'revers': False},
    {'ip': '192.168.43.187', 'revers': False},
    {'ip': '192.168.43.188', 'revers': False},
    {'ip': '192.168.43.189', 'revers': False},
    {'ip': '192.168.43.190', 'revers': False},
    {'ip': '192.168.43.192', 'revers': False},
    {'ip': '192.168.43.193', 'revers': False},
    {'ip': '192.168.43.194', 'revers': False},
    {'ip': '192.168.43.195', 'revers': False},
    {'ip': '192.168.43.196', 'revers': False},
    {'ip': '192.168.43.197', 'revers': False},
    {'ip': '192.168.43.198', 'revers': False},
    {'ip': '192.168.43.199', 'revers': False},
    {'ip': '192.168.43.200', 'revers': False},
    {'ip': '192.168.43.201', 'revers': False},
]

# %%
import socket
import cv2
import numpy as np

# Define ESP devices
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

pixel_bytes = bytearray(140*3)
def send_columns_to_esps():
    # Load image from file (e.g., saved from TOP)
    image_path = "jpg_out/snapshot.png"
    frame = cv2.imread(image_path)

    if frame is None:
        print("Failed to read image.")
        return

    # Resize to width = 70 if it's larger
    h, w, _ = frame.shape
    print( frame.shape)
    if w > 70:
        frame = cv2.resize(frame, (70, h), interpolation=cv2.INTER_AREA)
        h, w, _ = frame.shape

    # Send to each ESP (in round-robin or mapped logic)
    for i, esp in enumerate(esp_ip):
        row  = i*(h//len(esp_ip))
        print(row)
        column_data = frame[row, :, :]  # shape (h, 3)
        for col in range(w):
            r, g, b = column_data[col]
            # pixel_bytes.extend([r, g, b])
            pixel_bytes[col*3] = int(float(b)/1)
            pixel_bytes[col*3+1] = int(float(g)/1)
            pixel_bytes[col*3+2] = int(float(r)/1)

        # Add header byte
        data = b'\xAA'+ pixel_bytes[:3*w]
        print(len(data)/3)

        try:
            sock.sendto(data, (esp['ip'], 8266))
            # sock.close()
        except Exception as er:
            print(f"Failed to send to {esp['ip']}: {er}")
send_columns_to_esps()
# Out:
# (256, 35, 3)
# 0
# 35.333333333333336
# 2
# 35.333333333333336
# 4
# 35.333333333333336
# 6
# 35.333333333333336
# 8
# 35.333333333333336
# 10
# 35.333333333333336
# 12
# 35.333333333333336
# 14
# 35.333333333333336
# 16
# 35.333333333333336
# 18
# 35.333333333333336
# 20
# 35.333333333333336
# 22
# 35.333333333333336
# 24
# 35.333333333333336
# 26
# 35.333333333333336
# 28
# 35.333333333333336
# 30
# 35.333333333333336
# 32
# 35.333333333333336
# 34
# 35.333333333333336
# 36
# 35.333333333333336
# 38
# 35.333333333333336
# 40
# 35.333333333333336
# 42
# 35.333333333333336
# 44
# 35.333333333333336
# 46
# 35.333333333333336
# 48
# 35.333333333333336
# 50
# 35.333333333333336
# 52
# 35.333333333333336
# 54
# 35.333333333333336
# 56
# 35.333333333333336
# 58
# 35.333333333333336
# 60
# 35.333333333333336
# 62
# 35.333333333333336
# 64
# 35.333333333333336
# 66
# 35.333333333333336
# 68
# 35.333333333333336
# 70
# 35.333333333333336
# 72
# 35.333333333333336
# 74
# 35.333333333333336
# 76
# 35.333333333333336
# 78
# 35.333333333333336
# 80
# 35.333333333333336
# 82
# 35.333333333333336
# 84
# 35.333333333333336
# 86
# 35.333333333333336
# 88
# 35.333333333333336
# 90
# 35.333333333333336
# 92
# 35.333333333333336
# 94
# 35.333333333333336
# 96
# 35.333333333333336
# 98
# 35.333333333333336
# 100
# 35.333333333333336
# 102
# 35.333333333333336
# 104
# 35.333333333333336
# 106
# 35.333333333333336
# 108
# 35.333333333333336
# 110
# 35.333333333333336
# 112
# 35.333333333333336
# 114
# 35.333333333333336
# 116
# 35.333333333333336
# 118
# 35.333333333333336
# 120
# 35.333333333333336
# 122
# 35.333333333333336
# 124
# 35.333333333333336
# 126
# 35.333333333333336
# 128
# 35.333333333333336
# 130
# 35.333333333333336
# 132
# 35.333333333333336
# 134
# 35.333333333333336
# 136
# 35.333333333333336
# 138
# 35.333333333333336
# 140
# 35.333333333333336
# 142
# 35.333333333333336
# 144
# 35.333333333333336
# 146
# 35.333333333333336
# 148
# 35.333333333333336
# 150
# 35.333333333333336
# 152
# 35.333333333333336
# 154
# 35.333333333333336
# 156
# 35.333333333333336
# 158
# 35.333333333333336
# 160
# 35.333333333333336
# 162
# 35.333333333333336
# 164
# 35.333333333333336
# 166
# 35.333333333333336
# 168
# 35.333333333333336
# 170
# 35.333333333333336
# 172
# 35.333333333333336
# 174
# 35.333333333333336
# 176
# 35.333333333333336
# 178
# 35.333333333333336
# 180
# 35.333333333333336
# 182
# 35.333333333333336
# 184
# 35.333333333333336
# 186
# 35.333333333333336
# 188
# 35.333333333333336
# 190
# 35.333333333333336
# 192
# 35.333333333333336
# 194
# 35.333333333333336
# 196
# 35.333333333333336
# 198
# 35.333333333333336
# 200
# 35.333333333333336

# %%
import subprocess

esp_ip = [
    {'ip': f'192.168.43.{i}', 'revers': False}
    for i in range(101, 210)
]

def is_pingable(ip):
    try:
        result = subprocess.run(
            ['ping', '-n' if subprocess.os.name == 'nt' else '-c', '1', ip],
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL
        )
        return result.returncode == 0
    except Exception:
        return False

available_ips = [device for device in esp_ip if is_pingable(device['ip'])]

# Print copy-pasteable Python list
print("available_esp_ip = [")
for device in available_ips:
    print(f"    {device},")
print("]")
# Out:
# available_esp_ip = [
#     {'ip': '192.168.43.102', 'revers': False},
#     {'ip': '192.168.43.103', 'revers': False},
#     {'ip': '192.168.43.104', 'revers': False},
#     {'ip': '192.168.43.106', 'revers': False},
#     {'ip': '192.168.43.107', 'revers': False},
#     {'ip': '192.168.43.108', 'revers': False},
#     {'ip': '192.168.43.109', 'revers': False},
#     {'ip': '192.168.43.111', 'revers': False},
#     {'ip': '192.168.43.112', 'revers': False},
#     {'ip': '192.168.43.113', 'revers': False},
#     {'ip': '192.168.43.114', 'revers': False},
#     {'ip': '192.168.43.115', 'revers': False},
#     {'ip': '192.168.43.116', 'revers': False},
#     {'ip': '192.168.43.117', 'revers': False},
#     {'ip': '192.168.43.118', 'revers': False},
#     {'ip': '192.168.43.119', 'revers': False},
#     {'ip': '192.168.43.120', 'revers': False},
#     {'ip': '192.168.43.121', 'revers': False},
#     {'ip': '192.168.43.123', 'revers': False},
#     {'ip': '192.168.43.137', 'revers': False},
#     {'ip': '192.168.43.145', 'revers': False},
#     {'ip': '192.168.43.158', 'revers': False},
#     {'ip': '192.168.43.168', 'revers': False},
#     {'ip': '192.168.43.172', 'revers': False},
#     {'ip': '192.168.43.176', 'revers': False},
#     {'ip': '192.168.43.191', 'revers': False},
# ]

# %%
import websocket
import json


def on_message(ws, message):
    values = json.loads(message)['values']
    x = values[0]
    y = values[1]
    z = values[2]
    print("x = ", x , "y = ", y , "z = ", z )

def on_error(ws, error):
    print("error occurred ", error)
    
def on_close(ws, close_code, reason):
    print("connection closed : ", reason)
    
def on_open(ws):
    print("connected")
    

def connect(url):
    ws = websocket.WebSocketApp(url,
                              on_open=on_open,
                              on_message=on_message,
                              on_error=on_error,
                              on_close=on_close)

    ws.run_forever()
 
 
connect("ws://192.168.43.158:8080/sensor/connect?type=android.sensor.accelerometer")
# Out:
# connected
# x =  0.22061607 y =  -0.048169203 z =  9.842504
# x =  0.22324958 y =  -0.047211565 z =  9.8398695
# x =  0.22229195 y =  -0.046732746 z =  9.834603
# x =  0.21798258 y =  -0.042423364 z =  9.829814
# x =  0.43919736 y =  -0.64717275 z =  9.917917
# x =  4.919993 y =  -0.21910784 z =  13.955325
# x =  -2.1153061 y =  -0.901426 z =  5.2020216
# x =  0.54405886 y =  0.58818215 z =  10.089814
# x =  1.109545 y =  1.5755087 z =  9.825505
# x =  0.87157154 y =  1.4136674 z =  9.650736
# x =  1.2546275 y =  1.8225796 z =  9.477404
# x =  0.98074245 y =  2.073481 z =  9.483627
# x =  0.8667833 y =  2.1381218 z =  9.558324
# x =  0.86821973 y =  2.0888035 z =  9.454899
# x =  0.700154 y =  2.3851929 z =  10.171692
# x =  -1.7753441 y =  -1.148497 z =  8.774496
# x =  -1.4961922 y =  -1.7714417 z =  8.785988
# x =  4.6963835 y =  -0.4546872 z =  6.646142
# x =  8.441233 y =  1.2537417 z =  -6.028695
# x =  10.30815 y =  0.90468204 z =  -3.912312
# x =  5.5874662 y =  0.053340577 z =  3.990129
# x =  -5.264982 y =  -2.8789515 z =  7.121132
# x =  -2.1488233 y =  -2.122895 z =  8.388088
# x =  8.329668 y =  1.6482891 z =  0.62211114
# x =  6.4024186 y =  0.5819575 z =  -7.864969
# x =  11.120775 y =  1.4122311 z =  0.14076042
# x =  -2.806482 y =  -2.6148827 z =  6.3095317
# x =  -7.044515 y =  -3.5279915 z =  5.6387053
# x =  3.9980247 y =  -0.64813036 z =  7.5764894
# x =  9.958851 y =  0.6556958 z =  -0.09492171
# x =  9.097456 y =  -0.7924945 z =  6.6147795
# x =  -2.335563 y =  -1.3450525 z =  7.622935
# x =  -3.11987 y =  -1.9828405 z =  6.990893
# x =  0.14089258 y =  -2.927791 z =  10.524582
# x =  3.8802352 y =  -2.142048 z =  9.7041235
# x =  3.4691684 y =  -2.273484 z =  9.093151
# x =  1.3219014 y =  -0.20977087 z =  9.903074
# x =  0.18470457 y =  -0.022073526 z =  9.916481
# x =  0.18733808 y =  -0.01872179 z =  9.940661
# x =  0.18183167 y =  -0.023031171 z =  9.948321
# x =  0.18350755 y =  -0.025664676 z =  9.956701
# x =  0.1873381 y =  -0.018961197 z =  9.948561
# x =  0.18638048 y =  -0.02039766 z =  9.9432955
# x =  0.18949279 y =  -0.022552345 z =  9.938267
# x =  0.1870987 y =  -0.022312937 z =  9.94928
# x =  0.18566224 y =  -0.01560946 z =  9.950956
# x =  0.19260511 y =  -0.020876478 z =  9.949759
# x =  0.19116867 y =  -0.018961202 z =  9.950717
# x =  0.18853515 y =  -0.018482381 z =  9.952153
# x =  0.184944 y =  -0.020637069 z =  9.952871
# x =  0.18374695 y =  -0.021115888 z =  9.946406
# x =  0.1825499 y =  -0.020158252 z =  9.944971
# x =  0.19021103 y =  -0.022791756 z =  9.956223
# error occurred
# connection closed :  None
